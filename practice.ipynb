# %% [markdown]
# <a href="https://colab.research.google.com/github/ambreenraheem/PythonEdge_Pro_online_course/blob/main/practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Name: Ambreen

# %%
# I am practicing
print("Hello, this is ambreen and i am teaching python.")
# Out:
# Hello, this is ambreen and i am teaching python.

# %%
def greet():
  print("hello!")

# Calling function
greet()
# Out:
# hello!
